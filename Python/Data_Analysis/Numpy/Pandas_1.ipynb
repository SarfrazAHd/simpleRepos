# %% [markdown]
# # Pandas_series

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Nizam\\Downloads\\mushroom_dataset.csv")
df
# Out:
#      cap-shape cap-surface cap-color  bruises    odor gill-attachment  \
# 0       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 1       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 2       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 3       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 4       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 5       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 6       CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 7       CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 8       CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 9       CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 10      CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 11      CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# ...

# %%
df['odor']
# Out:
# 0       ALMOND
# 1       ALMOND
# 2       ALMOND
# 3       ALMOND
# 4       ALMOND
# 5       ALMOND
# 6        ANISE
# 7        ANISE
# 8        ANISE
# 9        ANISE
# 10       ANISE
# 11       ANISE
# 12      ALMOND
# 13      ALMOND
# 14      ALMOND
# 15      ALMOND
# 16      ALMOND
# 17      ALMOND
# 18       ANISE
# 19       ANISE
# 20       ANISE
# 21       ANISE
# 22       ANISE
# 23       ANISE
# 24      ALMOND
# 25      ALMOND
# 26      ALMOND
# 27      ALMOND
# 28      ALMOND
# 29      ALMOND
#          ...
# 8386      NONE
# 8387      NONE
# 8388      NONE
# 8389      NONE
# 8390      NONE
# 8391      NONE
# 8392      NONE
# 8393      NONE
# 8394      NONE
# 8395      NONE
# 8396      NONE
# 8397      NONE
# 8398      NONE
# 8399      NONE
# 8400      NONE
# 8401      NONE
# 8402      NONE
# 8403      NONE
# 8404      NONE
# 8405      NONE
# 8406      NONE
# 8407      NONE
# 8408      NONE
# 8409      NONE
# 8410      NONE
# 8411      NONE
# 8412      NONE
# ...
