# %%
import pandas as pd

df = pd.read_csv('school_grades_dataset.csv')
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2    G3
# 0      4        3      4     1     3      4        0  11  11   NaN
# 1      5        3      3     1     1      3        9  11  11   NaN
# 2      4        3      2     2     3      3       12  13  12   NaN
# 3      3        2      2     1     1      5        0  14  14  14.0
# 4      4        3      2     1     2      5        0  11  13  13.0
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (22, 33)

# %%
df2 = pd.read_csv("school_grades_dataset.csv", nrows=2, skip_blank_lines=True)
df2
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     3      4        0  11  11 NaN
# 1      5        3      3     1     1      3        9  11  11 NaN
#
# [2 rows x 33 columns]

# %%
df.sample(5)
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 8      GP   M   15       U     LE3       A     3     2  services    other
# 5      GP   M   16       U     LE3       T     4     3  services    other
# 7      GP   F   17       U     GT3       A     4     4     other  teacher
# 4      GP   F   16       U     GT3       T     3     3     other    other
# 14     GP   M   15       U     GT3       A     2     2     other    other
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2    G3
# 8   ...      4        2      2     1     1      1        0  15  16  17.0
# 5   ...      5        4      2     1     2      5        6  12  12  13.0
# 7   ...      4        1      4     1     1      1        2  10  13  13.0
# 4   ...      4        3      2     1     2      5        0  11  13  13.0
# 14  ...      4        5      2     1     1      3        0  14  14  15.0
#
# [5 rows x 33 columns]

# %%
df[['school', 'sex']]
# Out:
#    school sex
# 0      GP   F
# 1      GP   F
# 2      GP   F
# 3      GP   F
# 4      GP   F
# 5      GP   M
# 6      GP   M
# 7      GP   F
# 8      GP   M
# 9      GP   M
# 10     GP   F
# 11     GP   F
# 12     GP   M
# 13     GP   M
# 14     GP   M
# 15     GP   F
# 16     GP   F
# 17     GP   F
# 18     GP   M
# 19     GP   M
# 20     GP   M
# 21     GP   M

# %%
df.school
# Out:
# 0     GP
# 1     GP
# 2     GP
# 3     GP
# 4     GP
# 5     GP
# 6     GP
# 7     GP
# 8     GP
# 9     GP
# 10    GP
# 11    GP
# 12    GP
# 13    GP
# 14    GP
# 15    GP
# 16    GP
# 17    GP
# 18    GP
# 19    GP
# 20    GP
# 21    GP
# Name: school, dtype: object

# %%
df[df.sex =="F"]
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1      GP   F   17       U     GT3       T     1     1   at_home     other
# 2      GP   F   15       U     LE3       T     1     1   at_home     other
# 3      GP   F   15       U     GT3       T     4     2    health  services
# 4      GP   F   16       U     GT3       T     3     3     other     other
# 7      GP   F   17       U     GT3       A     4     4     other   teacher
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# 11     GP   F   15       U     GT3       T     2     1  services     other
# 15     GP   F   16       U     GT3       T     4     4    health     other
# 16     GP   F   16       U     GT3       T     4     4  services  services
# 17     GP   F   16       U     GT3       T     3     3     other     other
#
# ...

# %%
df[df.sex =="F"][['age', 'school','Mjob']].head()
# Out:
#    age school     Mjob
# 0   18     GP  at_home
# 1   17     GP  at_home
# 2   15     GP  at_home
# 3   15     GP   health
# 4   16     GP    other

# %%
df['age'].count()
# Out:
# 22
