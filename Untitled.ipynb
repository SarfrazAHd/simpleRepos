# %%
import matplotlib.pyplot as plt

expenditure=[2500, 3500, 1000, 500]
lbl="Food", "Rent", "Transport", "Mobile/others"

plt.pie(expenditure, labels=lbl, autopct="%1.1ff%%")
plt.axis("equal")
# Out:
# (-1.1287681866547081,
#  1.1013699239310473,
#  -1.1287681756536447,
#  1.1013699217344943)
